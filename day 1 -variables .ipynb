# %% [markdown]
# # Python Variables
#
# Variables are  used to store data in python.
#
# Example:
# name="Kanishka"
#
# Here ,"name" is a variable

# %%
print("HELLO KANSIHKA")
# Out:
# HELLO KANSIHKA

# %% [markdown]
# # String Variables
#
# A string variables store  text data.

# %%
name="KANISHKA"
print(name)
# Out:
# KANISHKA

# %% [markdown]
# # Integer Variable
#
#  An Integer variables stores whole numbers.

# %%
age=18
print(age)
# Out:
# 18

# %% [markdown]
# # Addition program
#  This program adds two numbers

# %%
a = 10 
b =20

print(a+b)
# Out:
# 30

# %% [markdown]
# # User Input Program
#
#   The input () function is used to take input from the user

# %%
name= input("Enter your name:")
print ("Hello ",name )
# Out:
# Hello  kanishka

# %% [markdown]
# # Age Program
#  This program stores and print ages

# %%
age=18

print("My age is:",age)
# Out:
# My age is: 18

# %% [markdown]
# # Calculator Program
# This program adds two numbers.

# %%
a= 15
b=25
product=a*b

print ("The product is:",product)
# Out:
# The product is: 375

# %% [markdown]
# # Multiple Variables
#
# Python can stores multiple values.

# %%
name = "Kanshika"
city = "Bangalore"
course = "Python"


print(name)
print(city)
print(course)
# Out:
# Kanshika
# Bangalore
# Python

# %% [markdown]
# # Type  Function
# The type function () show datatype of variable

# %%
a= 10
b=10.5
c="Python"


print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
fav_food = "Pizza"
print(fav_food)
# Out:
# Pizza

# %%
marks=95
print(marks)
# Out:
# 95

# %%
a=90
b=70

print(a+b)
# Out:
# 160

# %% [markdown]
# # MY INTRODUCTION PROGRAM
#
#  TO INTERVIEW MY SELF IN CODING WAY

# %%
name = "Kanshika"
age = 18
city = "Bangalore"
hobby = "Coding"
college = "MCU COLLEGE"
fav_subject= "AI"

print(name)
print(age)
print(city) 
print(hobby)
print(college)
print(fav_subject)
# Out:
# Kanshika
# 18
# Bangalore
# Coding
# MCU COLLEGE
# AI
