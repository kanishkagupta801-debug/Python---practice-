# %% [markdown]
# # Modules

# %% [markdown]
# # What is Modules???
#
# A Module is a file containing Python file that contains functions,variables,and code that can be reused .
#
# Instead of writing everything youself,you can import modules and use thier features.

# %%
import math

print(math.sqrt (25))
# Out:
# 5.0

# %% [markdown]
# math Module  ko python me laata hai .

# %% [markdown]
# math.sqrt(25)
#
# 25 ka square root nikalta hai

# %% [markdown]
# # Common Math Functions :

# %%
import math 

print(math.sqrt(64))
print(math.pow(2,3))
print(math.factorial(5))
# Out:
# 8.0
# 8.0
# 120

# %% [markdown]
# sqrt()= square root
# pow() = power
# factorial()=factorial

# %%
import math
number=49

print("Square Root =",
      math.sqrt(number))
# Out:
# Square Root = 7.0

# %% [markdown]
# # Import Specific Functions
#
# Instead of importing the  whole module,we can import specific functions.

# %%
from math import sqrt 

print (sqrt(81))
# Out:
# 9.0

# %%
import math

print(math.factorial(4))
# Out:
# 24

# %% [markdown]
# # Random Module :
#
# The Random module is used to generate random values
#
# - Random Number
#
# - Dice Roll
#
# - Random Choice

# %%
import random
print (random.randint(1,10))
# Out:
# 7

# %%
import random

print(random.randint(100,999))
# Out:
# 773

# %% [markdown]
# # Random Choice

# %%
import random
fruits=["Apple","Banana","Mango","Orange"]

print(random.choice(fruits))
# Out:
# Mango

# %% [markdown]
# # 🎲 MINI PROJECT -DICE ROLLER

# %%
import random

dice= random.randint(1,6)

print("Dice Rolled:" ,dice )
# Out:
# Dice Rolled: 1

# %% [markdown]
# # 🎮 Fun Program

# %%
import random

names =  ["KANISHKA","AMAN","RIYA","NEHA"]

winner = random.choice(names)

print("winner is:",winner)
# Out:
# winner is: KANISHKA

# %%
import random

print(random.randint(1,8))
# Out:
# 7
